# %% [markdown]
# <a href="https://colab.research.google.com/github/GOVINDFROMINDIA/PYTHON-FOR-DATA-SCIENCE/blob/main/untitled.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy   as np

import os
import pandas as pd


os.chdir("/content")
cars_data=pd.read_csv('toyota.csv')

plt.plot(cars_data["KM"],cars_data["Price"],c='Red')
plt.plot(cars_data["Age"],cars_data["Price"],c='Green')

plt.title("TOYOTA COSTFACTOR")

plt.ylabel("PRICE")

plt.show()
